# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import requests 
import time 
import openweathermapy as ow 
import openweathermapy.core as owm 

# %cd "C:\Users\kwlei\Documents\GitHub\WeatherReport"


# Import API key
from api_key import api_key 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy 

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-58, 73)
lng_range = (-180, 180)


# produce some output 
print("some output")
# Out:
# C:\Users\kwlei\Documents\GitHub\WeatherReport
# some output

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)


#  utu /watch?v=AVF-HyplZqo @ T:s=300

cityGrab_df = pd.DataFrame(cities, columns=["NAME"])
cityGrab_df.to_csv('cityGrab.csv', index=False)




# Print the city count to confirm sufficient count
# len(cities) 
len(cities)
# Out:
# 618

# %%
cityGrab_df.head()
# Out:
#           NAME
# 0   georgetown
# 1  terrace bay
# 2       harsin
# 3     cururupu
# 4      kahului

# %%
AllCity_load = "AllCity.csv" 
AllCity_df = pd.read_csv(AllCity_load) 
AllCity_df = pd.DataFrame(AllCity_df)

citySample_df = cityGrab_df[['NAME']].merge(AllCity_df[['NAME', 'UWM_ID']], on='NAME', how='left') 
citySample_df = citySample_df.dropna(how="any")
cityCodes_df = citySample_df['UWM_ID'].astype(np.int64)
cityCodes_df = pd.DataFrame(cityCodes_df)

cityCodes_df.dtypes
# cityCodes_df
# Out:
# UWM_ID    int64
# dtype: object

# %%
citySample_df.to_csv('citySample.csv', index=False)
cityCodes_df.to_csv('cityCodes.csv', index=False)

# %%
citySample000 = citySample_df.iloc[0:50] 
citySample050 = citySample_df.iloc[50:100] 
citySample100 = citySample_df.iloc[100:150] 
citySample150 = citySample_df.iloc[150:200] 
citySample200 = citySample_df.iloc[200:250] 
citySample250 = citySample_df.iloc[250:300] 
citySample300 = citySample_df.iloc[300:350] 
citySample350 = citySample_df.iloc[350:400] 
citySample400 = citySample_df.iloc[400:450] 
citySample450 = citySample_df.iloc[450:500] 
citySample500 = citySample_df.iloc[500:550] 
citySample550 = citySample_df.iloc[550:600] 
citySample600 = citySample_df.iloc[600:650] 
citySample650 = citySample_df.iloc[650:700] 

citySample000_df = pd.DataFrame(citySample000)
citySample050_df = pd.DataFrame(citySample050)
citySample100_df = pd.DataFrame(citySample100)
citySample150_df = pd.DataFrame(citySample150)
citySample200_df = pd.DataFrame(citySample200)
citySample250_df = pd.DataFrame(citySample250)
citySample300_df = pd.DataFrame(citySample300)
citySample350_df = pd.DataFrame(citySample350)
citySample400_df = pd.DataFrame(citySample400)
citySample450_df = pd.DataFrame(citySample450)
citySample500_df = pd.DataFrame(citySample500)
citySample550_df = pd.DataFrame(citySample550)
citySample600_df = pd.DataFrame(citySample600)
citySample650_df = pd.DataFrame(citySample650)

# citySample200_df.tail()
# citySample200_df.dtypes

# %%
# Create settings dictionary with information we're interested in
settings = {"units": "metric", "appid": api_key}

# %%
#####  GET FIRST FIFTY CITIES ######
settings = {"units": "metric", "appid": api_key}  
weather_data000 = [] 
for index, row in citySample000_df.iterrows(): 
    weather_data000.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample000_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data000]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data000 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data000

# %%
weather000_df = pd.DataFrame(weather_data000)
weather000_df = weather000_df.to_csv('weather000.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-238-0e54c8219b72> in <module>
# ----> 1 weather000_df = pd.DataFrame(weather_data000)
#       2 weather000_df = weather000_df.to_csv('weather000.csv', index=False)
#
# NameError: name 'weather_data000' is not defined

# %%
#####  GET SECOND FIFTY CITIES ######
weather_data = [] 
for index, row in citySample050_df.iterrows(): 
    weather_data.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample050_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
#weather_data111 = weather_data

# %%
# weather050_df = pd.DataFrame(weather_data) 
# weather050_df = weather050_df.to_csv('weather050.csv', index=False)
# Out:
#                       name sys.country  coord.lat  coord.lon  main.temp  \
# chokurdakh      Chokurdakh          RU      70.62     147.90       4.85
# mahebourg        Mahebourg          MU     -20.41      57.70      23.32
# bembereke        Bembereke          BJ      10.23       2.66      30.05
# port alfred    Port Alfred          ZA     -33.59      26.89      19.44
# san patricio  San Patricio          PY     -26.98     -56.83      14.15
#
#               main.humidity  clouds.all  wind.speed          dt
# chokurdakh               58           5        4.98  1568375536
# mahebourg                64          75        6.70  1568375537
# bembereke                64          25        2.24  1568375537
# port alfred              55          98        5.36  1568375538
# san patricio             86          64        2.61  1568375538

# %%
weather050_df = pd.DataFrame(weather_data1)
weather050_df.to_csv('weather050.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-237-9c7f898a3f22> in <module>
#       1 # weather050_df = pd.DataFrame(weather_data1)
# ----> 2 weather050_df.to_csv('weather050.csv', index=False)
#
# NameError: name 'weather050_df' is not defined

# %%
#####  GET 100th through 149th CITIES ######
settings = {"units": "metric", "appid": api_key}  
weather_data100 = [] 
for index, row in citySample100_df.iterrows(): 
    weather_data100.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample100_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data100]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
# weather_data

# %%
weather100_df = pd.DataFrame(weather_data)
weather100_df = weather100_df.to_csv('weather100.csv', index=False)

# %%
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
#####  GET 150th through 199th CITIES ######
weather_data150 = []
settings = {"units": "metric", "appid": api_key}  
for index, row in citySample150_df.iterrows(): 
    weather_data150.append(ow.get_current(row[0], **settings))

# %%
#####  GET 200th to 249th CITIES ######
weather_data200 = [] 
for index, row in citySample200_df.iterrows(): 
    weather_data200.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample200_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data200]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data200 = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather200_df = pd.DataFrame(weather_data200)
weather200_df = weather200_df.to_csv('weather200.csv', index=False)

# %%
weather_data450 = []

# %%
settings = {"units": "metric", "appid": api_key}  
weather_data450 = []
for index, row in citySample450_df.iterrows(): 
    weather_data450.append(ow.get_current(row[0], **settings))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-219-bf8f181b155a> in <module>
#       2 weather_data450 = []
#       3 for index, row in citySample450_df.iterrows():
# ----> 4     weather_data450.append(ow.get_current(row[0], **settings))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
# ...

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample450_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data450]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data450 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data450

# %%
weather_data450 = weather_data 
weather450_df = pd.DataFrame(weather_data)
weather450_df = weather450_df.to_csv('weather450.csv', index=False)

# %%
settings = {"units": "metric", "appid": api_key}  
weather_data500 = []
for index, row in citySample500_df.iterrows(): 
    weather_data500.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample500_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data500]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data500 = pd.DataFrame(data, index=cities, columns=column_names)
#weather_data500

# %%
weather500_df = pd.DataFrame(weather_data500)
weather500_df = weather500_df.to_csv('weather500.csv', index=False)

# %%
weather500_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-249-80d64f933258> in <module>
# ----> 1 weather500_df.dtypes
#
# AttributeError: 'NoneType' object has no attribute 'dtypes'

# %%
settings = {"units": "metric", "appid": api_key}  
weather_data550 = []
for index, row in citySample550_df.iterrows(): 
    weather_data.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample550_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data550]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data550 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data550
# Out:
# Empty DataFrame
# Columns: [name, sys.country, coord.lat, coord.lon, main.temp, main.humidity, clouds.all, wind.speed, dt]
# Index: []

# %%
weather_data550 = weather_data 
weather550_df = pd.DataFrame(weather_data)
weather550_df = weather550_df.to_csv('weather550.csv', index=False)

# %%
settings = {"units": "metric", "appid": api_key}  
for index, row in citySample500_df.iterrows(): 
    weather_data.append(ow.get_current(row[0], **settings))

# %%
weather_df = pd.DataFrame(weather_data)
weather_df = weather_df.to_csv('weatherOUT.csv', index=False)

# %%
weather_load = "weatherOUT.csv" 
weather99 = pd.read_csv(weather_load) 
weather99_df = pd.DataFrame(weather99)
cityNames = weather99_df['name'].astype(str)
cityNames_df = pd.DataFrame(cityNames)

# %%
cityNames_df.tail()
# Out:
#              name
# 150       Shimoda
# 151  Rio Gallegos
# 152      Rajpipla
# 153         Luena
# 154     Ketchikan

# %%
weather99_df
# Out:
#          base        clouds  cod                           coord          dt  \
# 0    stations   {'all': 40}  200     {'lon': -58.16, 'lat': 6.8}  1568393077
# 1    stations   {'all': 41}  200   {'lon': -15.83, 'lat': 11.28}  1568393372
# 2    stations    {'all': 0}  200   {'lon': 22.13, 'lat': -30.97}  1568393373
# 3    stations   {'all': 75}  200    {'lon': 25.68, 'lat': 35.02}  1568393373
# 4    stations   {'all': 99}  200   {'lon': -56.15, 'lat': 72.79}  1568393373
# 5    stations   {'all': 97}  200     {'lon': 79.99, 'lat': 14.5}  1568393373
# 6    stations   {'all': 40}  200   {'lon': 18.42, 'lat': -33.93}  1568393221
# 7    stations   {'all': 53}  200   {'lon': 12.15, 'lat': -15.19}  1568393374
# 8    stations   {'all': 20}  200   {'lon': -78.17, 'lat': 18.44}  1568393374
# 9    stations    {'all': 1}  200  {'lon': -155.08, 'lat': 19.71}  1568393233
# 10   stations    {'all': 0}  200     {'lon': 7.39, 'lat': 18.74}  1568393374
# ...

# %%
summary = ['NAME', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = cityNames_df['NAME'].values 
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NAME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-ba737eac47ff> in <module>
# ...

# %%
# Create an "extracts" object to get the temperature, latitude, and longitude in each city
summary = summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = cityNames_df.values 

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather99_df]
column_names = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
weather_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-112-a33ca228a035> in <module>
#       4
#       5 # Create a Pandas DataFrame with the results
# ----> 6 data = [response(*summary) for response in weather99_df]
#       7 column_names = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
#       8 weather_data = pd.DataFrame(data, index=cities, columns=column_names)
#
# <ipython-input-112-a33ca228a035> in <listcomp>(.0)
#       4
#       5 # Create a Pandas DataFrame with the results
# ----> 6 data = [response(*summary) for response in weather99_df]
#       7 column_names = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
#       8 weather_data = pd.DataFrame(data, index=cities, columns=column_names)
#
# ...

# %%
#####  GET 200th to 249th CITIES ######
weather_data200 = [] 
for index, row in citySample200_df.iterrows(): 
    weather_data200.append(ow.get_current(row[0], **settings))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-152-4abf5dcd9e69> in <module>
#       2 weather_data200 = []
#       3 for index, row in citySample200_df.iterrows():
# ----> 4     weather_data200.append(ow.get_current(row[0], **settings))
#       5
#       6
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
# ...

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample200_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data200]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data200 = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather200_df = pd.DataFrame(weather_data200)
weather200_df = weather200_df.to_csv('weather200.csv', index=False)

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample150_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data150]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data150 = pd.DataFrame(data, index=cities, columns=column_names)
#weather_data150

# %%
weather150_df = pd.DataFrame(weather_data150)
weather150_df = weather150_df.to_csv('weather150.csv', index=False)

# %%
weather150_df

# %%
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######
#####  GET 200th to 249th CITIES ######

#####  GET 200th to 599th CITIES ######
weather_data200 = [] 
for index, row in citySample200_df.iterrows(): 
    weather_data200.append(ow.get_current(row[0], **settings))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-185-8b0c138645bd> in <module>
#      21 weather_data200 = []
#      22 for index, row in citySample200_df.iterrows():
# ---> 23     weather_data200.append(ow.get_current(row[0], **settings))
#      24
#      25
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
# ...

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample200_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data200]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data200 = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather200_df = pd.DataFrame(weather_data200)
weather200_df = weather200_df.to_csv('weather200.csv', index=False)

# %%
#weather_data200 = weather_data 
#weather200_df = pd.DataFrame(weather_data)
weather200_df = weather200_df.to_csv('weather200.csv', index=False)

# %%
citySample250_df
# Out:
#                         NAME     UWM_ID
# 293                 stepnyak  1518768.0
# 294               pijijiapan  3521476.0
# 295                  bontang  1648186.0
# 296                   aykhal  2027296.0
# 297                port said   358619.0
# 298                   kikwit  2314705.0
# 299               nouakchott  2377450.0
# 300            saint stephen  2638698.0
# 301                 belmonte  8010472.0
# 302                    kieta  2094027.0
# 303                le pradet  3002510.0
# 304                   padang  1633419.0
# 305                  urayasu  1849186.0
# 306              port-gentil  2396518.0
# 307                 saldanha  3361934.0
# 308                     brae  2654970.0
# 311                 cherskiy  2126199.0
# 312              bodden town  3580733.0
# 313                    mazyr   625324.0
# 314         puerto escondido  3520994.0
# 315          haines junction  5969025.0
# 317                taoudenni  2450173.0
# ...

# %%
#####  GET 250th to 299th CITIES ######
weather_data250 = [] 
for index, row in citySample250_df.iterrows(): 
    weather_data250.append(ow.get_current(row[0], **settings))

# %%
weather_df = pd.DataFrame(weather_data)

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample250_df['NAME'].values 

weather_df.reset_index()
weather_df = weather_df.drop(weather_df.index[51:90])

# %%
data = [response(*summary) for response in weather_df]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_df = pd.DataFrame(data, index=cities, columns=column_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-bb510612598d> in <module>
# ----> 1 data = [response(*summary) for response in weather_df]
#       2 column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
#       3 weather_df = pd.DataFrame(data, index=cities, columns=column_names)
#
# <ipython-input-80-bb510612598d> in <listcomp>(.0)
# ----> 1 data = [response(*summary) for response in weather_df]
#       2 column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
#       3 weather_df = pd.DataFrame(data, index=cities, columns=column_names)
#
# TypeError: 'str' object is not callable

# %%
weather = weather_data
weather_df = pd.DataFrame(weather_data)

# %%
#weather_df = weather_df.reshape(-1,9)


weather_df = pd.DataFrame(weather_df.values.reshape((-1, 9)))
                  
                  
                  
#mydf = pd.DataFrame(myvec.reshape(-1, 3))

# %%
data = [response(*summary) for response in weather_df]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_df = pd.DataFrame(data, index=cities, columns=column_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-bb510612598d> in <module>
# ----> 1 data = [response(*summary) for response in weather_df]
#       2 column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
#       3 weather_df = pd.DataFrame(data, index=cities, columns=column_names)
#
# <ipython-input-65-bb510612598d> in <listcomp>(.0)
# ----> 1 data = [response(*summary) for response in weather_df]
#       2 column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
#       3 weather_df = pd.DataFrame(data, index=cities, columns=column_names)
#
# TypeError: 'int' object is not callable

# %%
#weather_data250 = weather_data 
#weather250_df = pd.DataFrame(weather250)
weather250_df = weather250_df.to_csv('weather250.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-240-576c82d2e8e3> in <module>
#       1 #weather_data250 = weather_data
#       2 #weather250_df = pd.DataFrame(weather250)
# ----> 3 weather250_df = weather250_df.to_csv('weather250.csv', index=False)
#
# NameError: name 'weather250_df' is not defined

# %%
#####  GET 300th to 350th CITIES ######
weather_data300 = [] 
for index, row in citySample300_df.iterrows(): 
    weather_data.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample300_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)

# %%
# weather300 = weather_data 
# weather300_df = pd.DataFrame(weather300)
weather300_df = weather300_df.to_csv('weather300.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-241-6851c0faf431> in <module>
#       1 # weather300 = weather_data
#       2 # weather300_df = pd.DataFrame(weather300)
# ----> 3 weather300_df = weather300_df.to_csv('weather300.csv', index=False)
#
# NameError: name 'weather300_df' is not defined

# %%
#####  GET 350th to 399th CITIES ######
weather_data350 = [] 
for index, row in citySample350_df.iterrows(): 
    weather_data350.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample350_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data350]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)
# weather_data

# %%
weather350_df = pd.DataFrame(weather_data)
weather350_df = weather350_df.to_csv('weather350.csv', index=False)

# %%
#####  GET 400th to 450th CITIES ######
weather_data = [] 
for index, row in citySample400_df.iterrows(): 
    weather_data.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample400_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather_data400 = weather_data 
weather400_df = pd.DataFrame(weather_data)
weather400_df = weather400_df.to_csv('weather400.csv', index=False)

# %%
#################################################################
##################  WAITING WAITING WAITING #####################4
#################################################################
##################  WAITING WAITING WAITING #####################4
#################################################################
##################  WAITING WAITING WAITING #####################4
#################################################################
##################  WAITING WAITING WAITING #####################4
#################################################################



#####  GET 450th to 499th CITIES ######
weather_data450 = [] 
for index, row in citySample450_df.iterrows(): 
    weather_data450.append(ow.get_current(row[0], **settings))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-231-4bc389922911> in <module>
#      14 weather_data450 = []
#      15 for index, row in citySample450_df.iterrows():
# ---> 16     weather_data450.append(ow.get_current(row[0], **settings))
#      17
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
# ...

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample450_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data450]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data450 = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather450_df = pd.DataFrame(weather_data450)
weather450_df = weather450_df.to_csv('weather450.csv', index=False)

# %%
#################################################################
###########  NOT  NOT  ###########  NOT  NOT  ###########  NOT   NOT  ###########
#################################################################
#################################################################
#####  GET 500th to 549th CITIES ######
weather_data500 = [] 
for index, row in citySample500_df.iterrows(): 
    weather_data500.append(ow.get_current(row[0], **settings))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-155-441d9a2e2a83> in <module>
#       6 weather_data500 = []
#       7 for index, row in citySample500_df.iterrows():
# ----> 8     weather_data500.append(ow.get_current(row[0], **settings))
#       9
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
# ...

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample500_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data500]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data500 = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather500_df = pd.DataFrame(weather_data500)
weather500_df = weather500_df.to_csv('weather500.csv', index=False)

# %%
#####  GET 550th to 599th CITIES ######
#####  GET 550th to 599th CITIES ######
weather_data550 = [] 
for index, row in citySample550_df.iterrows(): 
    weather_data550.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample550_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data550]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data550 = pd.DataFrame(data, index=cities, columns=column_names)

# %%
weather550_df = pd.DataFrame(weather_data550)
weather550_df = weather550_df.to_csv('weather550.csv', index=False)

# %%
weather_df = pd.DataFrame(weather_data)
weather_df = weather_df.to_csv('weatherOUT.csv', index=False)

# %%
weather_load = "weatherOUT.csv" 
weather99 = pd.read_csv(weather_load) 
weather99_df = pd.DataFrame(weather99)
cityNames = weather99_df['name'].astype(str)
cityNames_df = pd.DataFrame(cityNames)

# %%
summary = ['NAME', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = cityNames_df['NAME'].values 
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NAME'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-75183dd62dd8> in <module>
# ...

# %%
data = [response(*summary) for response in weather_data300]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data300 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data300

# %%
#####  GET  CITIES  300 - 349 #####
settings = {"units": "metric", "appid": api_key}  
weather_data300 = [] 
for index, row in citySample300_df.iterrows(): 
    weather_data300.append(ow.get_current(row[0], **settings)) 

summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample300_df['NAME'].values 

data = [response(*summary) for response in weather_data300]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data300 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data300

# %%
#####  GET THIRD FIFTY CITIES 
settings = {"units": "metric", "appid": api_key}  
weather_data3 = [] 
for index, row in citySample100_df.iterrows(): 
    weather_data3.append(ow.get_current(row[0], **settings))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-260-f393fd998272> in <module>
#       3 weather_data3 = []
#       4 for index, row in citySample100_df.iterrows():
# ----> 5     weather_data3.append(ow.get_current(row[0], **settings))
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
# ...

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample100_df['NAME'].values 

settings = {"units": "metric", "appid": api_key}  
weather_data100 = [] 
for index, row in citySample350_df.iterrows(): 
    weather_data350.append(ow.get_current(row[0], **settings)) 

summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample350_df['NAME'].values 

data = [response(*summary) for response in weather_data350]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data350 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data350

# %%
data = [response(*summary) for response in weather_data3]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data3 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data3

# %%
#####  GET  CITIES  300 - 349 #####
settings = {"units": "metric", "appid": api_key}  
weather_data300 = [] 
for index, row in citySample300_df.iterrows(): 
    weather_data300.append(ow.get_current(row[0], **settings))

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample300_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data300]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data300 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data300.head()
# Out:
#                         name sys.country  coord.lat  coord.lon  main.temp  \
# savelugu            Savelugu          GH       9.63      -0.83      29.55
# makakilo city  Makakilo City          US      21.35    -158.09      25.58
# poya                    Poya          NC     -21.35     165.16      20.25
# bilma                  Bilma          NE      18.69      12.92      39.95
# klaksvik            Klaksvik          FO      62.23      -6.59      11.00
#
#                main.humidity  clouds.all  wind.speed          dt
# savelugu                  70          56        3.30  1568377143
# makakilo city             83          40        1.50  1568377143
# poya                      75          24        6.52  1568377143
# bilma                      9           0        6.49  1568377144
# klaksvik                  71          75        9.30  1568377144

# %%
weather300_df = pd.DataFrame(weather_data300)
weather300_df = weather300_df.to_csv('weather300.csv', index=False)

# %%
#####  GET  CITIES  350 - 399 #####
settings = {"units": "metric", "appid": api_key}  
weather_data350 = [] 
for index, row in citySample350_df.iterrows(): 
    weather_data350.append(ow.get_current(row[0], **settings))

# %%
# citySample350_df

# %%
summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample350_df['NAME'].values

# %%
data = [response(*summary) for response in weather_data350]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data350 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data350.head()

# %%
weather_data300.head()
# Out:
#                         name sys.country  coord.lat  coord.lon  main.temp  \
# savelugu            Savelugu          GH       9.63      -0.83      29.55
# makakilo city  Makakilo City          US      21.35    -158.09      25.58
# poya                    Poya          NC     -21.35     165.16      20.25
# bilma                  Bilma          NE      18.69      12.92      39.95
# klaksvik            Klaksvik          FO      62.23      -6.59      11.00
#
#                main.humidity  clouds.all  wind.speed          dt
# savelugu                  70          56        3.30  1568377143
# makakilo city             83          40        1.50  1568377143
# poya                      75          24        6.52  1568377143
# bilma                      9           0        6.49  1568377144
# klaksvik                  71          75        9.30  1568377144

# %%
weather350_df = pd.DataFrame(weather_data350) 
weather350_df.to_csv('weather351.csv', index=False)

# %%
# current_weather_paris = owm.get_current("Paris", **settings)
# print(f"Current weather object for Paris: {current_weather_paris}.")

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
summary = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]

# data = current_weather_paris(*summary)
# print(f"The current weather summary for Paris is: {data}.")

# %%
# Create an "extracts" object to get the temperature, latitude, and longitude in each city

citySample = citySample_df['City Name'].values

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data = pd.DataFrame(data, index=citySample, columns=column_names)
weather_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1666         blocks = form_blocks(arrays, names, axes)
# -> 1667         mgr = BlockManager(blocks, axes)
#    1668         mgr._consolidate_inplace()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     113         if do_integrity_check:
# --> 114             self._verify_integrity()
#     115
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     310             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 311                 construction_error(tot_items, block.shape[1:], self.axes)
# ...

# %%
weather_data
# Out:
#                                               name sys.country  coord.lat  \
# new norfolk                            New Norfolk          AU     -42.78
# high prairie                          High Prairie          CA      55.43
# avarua                                      Avarua          CK     -21.21
# lebu                                          Lebu          ET       8.96
# cockburn town                        Cockburn Town          TC      21.46
# albany                                      Albany          US      42.65
# snasa                                        Snasa          NO      64.25
# georgetown                              Georgetown          GY       6.80
# busselton                                Busselton          AU     -33.64
# margate                                    Margate          AU     -43.03
# chapais                                    Chapais          CA      49.78
# san jeronimo                          San Jeronimo          PE     -13.65
# ...

# %%
weather1_df = pd.DataFrame(weather_data1)

weather1_df.to_csv('weather1.csv', index=False)

weather1_df.head()
# Out:
#                         name sys.country  coord.lat  coord.lon  main.temp  \
# new norfolk      New Norfolk          AU     -42.78     147.06       9.69
# high prairie    High Prairie          CA      55.43    -116.48      11.05
# avarua                Avarua          CK     -21.21    -159.78      21.00
# lebu                    Lebu          ET       8.96      38.73      20.55
# cockburn town  Cockburn Town          TC      21.46     -71.14      28.65
#
#                main.humidity  clouds.all  wind.speed          dt
# new norfolk               70          20        3.60  1568375522
# high prairie              92         100        2.43  1568375523
# avarua                    88          40        1.00  1568375523
# lebu                      64          61        3.07  1568375523
# cockburn town             82          97        7.12  1568375463

# %%
weather_data2.tail()
# Out:
#                       name sys.country  coord.lat  coord.lon  main.temp  \
# chokurdakh      Chokurdakh          RU      70.62     147.90       4.85
# mahebourg        Mahebourg          MU     -20.41      57.70      23.36
# bembereke        Bembereke          BJ      10.23       2.66      30.05
# port alfred    Port Alfred          ZA     -33.59      26.89      19.44
# san patricio  San Patricio          PY     -26.98     -56.83      14.15
#
#               main.humidity  clouds.all  wind.speed          dt
# chokurdakh               58           5        4.98  1568376424
# mahebourg                64          75        6.70  1568376424
# bembereke                64          25        2.24  1568376425
# port alfred              54          98        4.92  1568376425
# san patricio             86          64        2.61  1568376425

# %%
weather100_df = pd.DataFrame(weather_data333)
weather100_df.to_csv('weather100.csv', index=False)

# %%
#weather_data3_df = pd.DataFrame(weather_data3)
#weather_data3_df.head()
citySample100a = citySample_df.iloc[650:700] 

citySample000_df = pd.DataFrame(citySample000)

settings = {"units": "metric", "appid": api_key}  
#weather_data3 = [] 
#for index, row in citySample400_df.iterrows(): 
#    weather_data3.append(ow.get_current(row[0], **settings)) 

summary = ['name', 'sys.country', 'coord.lat', 'coord.lon', 'main.temp', 'main.humidity', 'clouds.all', 'wind.speed', 'dt']
cities = citySample100_df['NAME'].values 

data = [response(*summary) for response in weather_data3]
column_names = ["name", "sys.country", "coord.lat", "coord.lon", "main.temp", "main.humidity", "clouds.all", "wind.speed", "dt"]
weather_data100 = pd.DataFrame(data, index=cities, columns=column_names)
weather_data100
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1666         blocks = form_blocks(arrays, names, axes)
# -> 1667         mgr = BlockManager(blocks, axes)
#    1668         mgr._consolidate_inplace()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in __init__(self, blocks, axes, do_integrity_check)
#     113         if do_integrity_check:
# --> 114             self._verify_integrity()
#     115
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _verify_integrity(self)
#     310             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# --> 311                 construction_error(tot_items, block.shape[1:], self.axes)
# ...

# %%
weather_data100.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-279-d287470731c6> in <module>
# ----> 1 weather_data100.head()
#
# NameError: name 'weather_data100' is not defined

# %%
weather_data150.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-280-cdeadd6ccc53> in <module>
# ----> 1 weather_data150.head()
#
# NameError: name 'weather_data150' is not defined

# %%
weather200_df = pd.DataFrame(weather_data200) 
weather200_df.to_csv('weather200.csv', index=False)

# %%
weather_data250.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-282-7fc499ac22bf> in <module>
# ----> 1 weather_data250.head()
#
# NameError: name 'weather_data250' is not defined

# %%
weather_data300.head()
# Out:
#                         name sys.country  coord.lat  coord.lon  main.temp  \
# savelugu            Savelugu          GH       9.63      -0.83      29.55
# makakilo city  Makakilo City          US      21.35    -158.09      25.58
# poya                    Poya          NC     -21.35     165.16      20.25
# bilma                  Bilma          NE      18.69      12.92      39.95
# klaksvik            Klaksvik          FO      62.23      -6.59      11.00
#
#                main.humidity  clouds.all  wind.speed          dt
# savelugu                  70          56        3.30  1568377143
# makakilo city             83          40        1.50  1568377143
# poya                      75          24        6.52  1568377143
# bilma                      9           0        6.49  1568377144
# klaksvik                  71          75        9.30  1568377144

# %%
weather350_df = pd.DataFrame(weather_data350) 
weather350_df.to_csv('weather350.csv', index=False)
#weather_data350.head()

# %%
weather_data400.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-244-ea8ee2b3340d> in <module>
# ----> 1 weather_data400.head()
#
# NameError: name 'weather_data400' is not defined

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
