# %%
# Dependencies and Setup
import matplotlib.pyplot as plt 
import pandas as pd 
import numpy as np 
import requests 
import time 
import openweathermapy as ow 
import openweathermapy.core as owm 

# %cd "C:\Users\kwlei\Documents\GitHub\WeatherReport"


# Import API key
from api_key import api_key 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy 


# Range of latitudes and longitudes
lat_range = (-55, 73)
lng_range = (-180, 180)

# produce some output 
print("some output")
# Out:
# C:\Users\kwlei\Documents\GitHub\WeatherReport
# some output

# %%
weather000_load = "weather000i.csv"
weather050_load = "weather050i.csv"
weather100_load = "weather100i.csv"
weather150_load = "weather150i.csv"
weather200_load = "weather200i.csv"
weather250_load = "weather250i.csv"
weather300_load = "weather300i.csv"
weather350_load = "weather350i.csv"
weather400_load = "weather400i.csv"
# weather450_load = "weather000.csv"
weather500_load = "weather500i.csv"
# weather550_load = "weather000.csv"
weather600_load = "weather600i.csv"

# %%
weather000_df = pd.read_csv(weather000_load)
weather050_df = pd.read_csv(weather050_load)
weather100_df = pd.read_csv(weather100_load)
weather150_df = pd.read_csv(weather150_load)
weather200_df = pd.read_csv(weather200_load)
weather250_df = pd.read_csv(weather250_load)
weather300_df = pd.read_csv(weather300_load)
weather350_df = pd.read_csv(weather350_load)
weather400_df = pd.read_csv(weather400_load)
# weather450_df = pd.read_csv(weather450_load)
weather500_df = pd.read_csv(weather500_load)
# weather550_df = pd.read_csv(weather550_load)
weather600_df = pd.read_csv(weather600_load)

# %%
weather000_df = pd.DataFrame(weather000_df)
weather050_df = pd.DataFrame(weather050_df)
weather100_df = pd.DataFrame(weather100_df)
weather150_df = pd.DataFrame(weather150_df)
weather200_df = pd.DataFrame(weather200_df)
weather250_df = pd.DataFrame(weather250_df)
weather300_df = pd.DataFrame(weather300_df)
weather350_df = pd.DataFrame(weather350_df)
weather400_df = pd.DataFrame(weather400_df)
# weather450_df = pd.DataFrame(weather450_df)
weather500_df = pd.DataFrame(weather500_df)
# weather550_df = pd.DataFrame(weather550_df)
weather600_df = pd.DataFrame(weather600_df)

# %%
weather600_df.dtypes
# Out:
# name              object
# sys.country       object
# coord.lat        float64
# coord.lon        float64
# main.temp        float64
# main.humidity      int64
# clouds.all         int64
# wind.speed       float64
# dt                 int64
# dtype: object

# %%
weather000_df = weather_df.to_csv('weather000bak.csv', index=False)
weather050_df = weather_df.to_csv('weather050bak.csv', index=False)
weather100_df = weather_df.to_csv('weather100bak.csv', index=False)
weather150_df = weather_df.to_csv('weather150bak.csv', index=False)
weather200_df = weather_df.to_csv('weather200bak.csv', index=False)
weather250_df = weather_df.to_csv('weather250bak.csv', index=False)
weather300_df = weather_df.to_csv('weather300bak.csv', index=False)
weather350_df = weather_df.to_csv('weather350bak.csv', index=False)
weather400_df = weather_df.to_csv('weather400bak.csv', index=False)

weather500_df = weather_df.to_csv('weather500bak.csv', index=False)

weather600_df = weather_df.to_csv('weather600bak.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-f413efdc4c57> in <module>
# ----> 1 weather000_df = weather_df.to_csv('weather000bak.csv', index=False)
#       2 weather050_df = weather_df.to_csv('weather050bak.csv', index=False)
#       3 weather100_df = weather_df.to_csv('weather100bak.csv', index=False)
#       4 weather150_df = weather_df.to_csv('weather150bak.csv', index=False)
#       5 weather200_df = weather_df.to_csv('weather200bak.csv', index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
weather_all = pd.concat([weather000_df, weather050_df])
weather000_df
# Out:
#                          name sys.country  coord.lat  coord.lon  main.temp  \
# 0                      Ayagoz          KZ      47.96      80.43      16.25
# 1                     Neuquen          AR     -38.95     -68.06       8.00
# 2                        Chuy          UY     -33.69     -53.46      10.65
# 3                     Rikitea          PF     -23.12    -134.97      22.05
# 4   Santa Isabel do Rio Negro          BR      -0.41     -65.02      27.25
# 5                  Nanortalik          GL      60.14     -45.24       4.55
# 6              Saint-Philippe          CA      45.36     -73.48      10.68
# 7                 Yellowknife          CA      62.45    -114.38       9.45
# 8                       Vaini          IN      15.34      74.49      25.00
# 9                    Columbus          US      32.46     -84.99      21.97
# 10                  Chebarkul          RU      54.98      60.37      17.45
# ...

# %%
weather050_df
# Out:
#                          name sys.country  coord.lat  coord.lon  main.temp  \
# 0                      Ayagoz          KZ      47.96      80.43      16.25
# 1                     Neuquen          AR     -38.95     -68.06       8.00
# 2                        Chuy          UY     -33.69     -53.46      10.65
# 3                     Rikitea          PF     -23.12    -134.97      22.05
# 4   Santa Isabel do Rio Negro          BR      -0.41     -65.02      27.25
# 5                  Nanortalik          GL      60.14     -45.24       4.55
# 6              Saint-Philippe          CA      45.36     -73.48      10.68
# 7                 Yellowknife          CA      62.45    -114.38       9.45
# 8                       Vaini          IN      15.34      74.49      25.00
# 9                    Columbus          US      32.46     -84.99      21.97
# 10                  Chebarkul          RU      54.98      60.37      17.45
# ...

# %%
weather500_df
# Out:
#                          name sys.country  coord.lat  coord.lon  main.temp  \
# 0                      Ayagoz          KZ      47.96      80.43      16.25
# 1                     Neuquen          AR     -38.95     -68.06       8.00
# 2                        Chuy          UY     -33.69     -53.46      10.65
# 3                     Rikitea          PF     -23.12    -134.97      22.05
# 4   Santa Isabel do Rio Negro          BR      -0.41     -65.02      27.25
# 5                  Nanortalik          GL      60.14     -45.24       4.55
# 6              Saint-Philippe          CA      45.36     -73.48      10.68
# 7                 Yellowknife          CA      62.45    -114.38       9.45
# 8                       Vaini          IN      15.34      74.49      25.00
# 9                    Columbus          US      32.46     -84.99      21.97
# 10                  Chebarkul          RU      54.98      60.37      17.45
# ...

# %%
weather_df = weather000_df 
weather_df = pd.DataFrame(weather_df)
weather_df.tail()
# Out:
#            name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 45    Ewa Beach          US      21.32    -158.01      25.38             83
# 46        Olean          US      42.08     -78.43      14.50            100
# 47   Baruun-Urt          MN      46.68     113.28       9.75             60
# 48    Boa Vista          BR       2.82     -60.67      30.00             62
# 49  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#     clouds.all  wind.speed          dt
# 45          75        7.28  1568380378
# 46          90        3.10  1568380379
# 47           0        2.63  1568380379
# 48           0        2.60  1568380379
# 49          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather050_df,ignore_index = True) 

weather_df.tail()
# Out:
#            name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 95    Ewa Beach          US      21.32    -158.01      25.38             83
# 96        Olean          US      42.08     -78.43      14.50            100
# 97   Baruun-Urt          MN      46.68     113.28       9.75             60
# 98    Boa Vista          BR       2.82     -60.67      30.00             62
# 99  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#     clouds.all  wind.speed          dt
# 95          75        7.28  1568380378
# 96          90        3.10  1568380379
# 97           0        2.63  1568380379
# 98           0        2.60  1568380379
# 99          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather100_df,ignore_index = True) 
weather_df.tail()
# Out:
#             name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 145    Ewa Beach          US      21.32    -158.01      25.38             83
# 146        Olean          US      42.08     -78.43      14.50            100
# 147   Baruun-Urt          MN      46.68     113.28       9.75             60
# 148    Boa Vista          BR       2.82     -60.67      30.00             62
# 149  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#      clouds.all  wind.speed          dt
# 145          75        7.28  1568380378
# 146          90        3.10  1568380379
# 147           0        2.63  1568380379
# 148           0        2.60  1568380379
# 149          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather150_df,ignore_index = True) 
weather_df.tail()
# Out:
#             name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 195    Ewa Beach          US      21.32    -158.01      25.38             83
# 196        Olean          US      42.08     -78.43      14.50            100
# 197   Baruun-Urt          MN      46.68     113.28       9.75             60
# 198    Boa Vista          BR       2.82     -60.67      30.00             62
# 199  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#      clouds.all  wind.speed          dt
# 195          75        7.28  1568380378
# 196          90        3.10  1568380379
# 197           0        2.63  1568380379
# 198           0        2.60  1568380379
# 199          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather200_df,ignore_index = True) 
weather_df.tail()
# Out:
#             name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 245    Ewa Beach          US      21.32    -158.01      25.38             83
# 246        Olean          US      42.08     -78.43      14.50            100
# 247   Baruun-Urt          MN      46.68     113.28       9.75             60
# 248    Boa Vista          BR       2.82     -60.67      30.00             62
# 249  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#      clouds.all  wind.speed          dt
# 245          75        7.28  1568380378
# 246          90        3.10  1568380379
# 247           0        2.63  1568380379
# 248           0        2.60  1568380379
# 249          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather250_df,ignore_index = True) 
weather_df.tail()
# Out:
#             name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 295    Ewa Beach          US      21.32    -158.01      25.38             83
# 296        Olean          US      42.08     -78.43      14.50            100
# 297   Baruun-Urt          MN      46.68     113.28       9.75             60
# 298    Boa Vista          BR       2.82     -60.67      30.00             62
# 299  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#      clouds.all  wind.speed          dt
# 295          75        7.28  1568380378
# 296          90        3.10  1568380379
# 297           0        2.63  1568380379
# 298           0        2.60  1568380379
# 299          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather300_df,ignore_index = True) 
weather_df.tail()
# Out:
#             name sys.country  coord.lat  coord.lon  main.temp  main.humidity  \
# 345    Ewa Beach          US      21.32    -158.01      25.38             83
# 346        Olean          US      42.08     -78.43      14.50            100
# 347   Baruun-Urt          MN      46.68     113.28       9.75             60
# 348    Boa Vista          BR       2.82     -60.67      30.00             62
# 349  Grand Gaube          MU     -20.01      57.66      22.12             78
#
#      clouds.all  wind.speed          dt
# 345          75        7.28  1568380378
# 346          90        3.10  1568380379
# 347           0        2.63  1568380379
# 348           0        2.60  1568380379
# 349          75        5.10  1568380379

# %%
weather_df = weather_df.append(weather350_df,ignore_index = True) 
weather_df.head()
# Out:
#                         name sys.country  coord.lat  coord.lon  main.temp  \
# 0                     Ayagoz          KZ      47.96      80.43      16.25
# 1                    Neuquen          AR     -38.95     -68.06       8.00
# 2                       Chuy          UY     -33.69     -53.46      10.65
# 3                    Rikitea          PF     -23.12    -134.97      22.05
# 4  Santa Isabel do Rio Negro          BR      -0.41     -65.02      27.25
#
#    main.humidity  clouds.all  wind.speed          dt
# 0             32          32        3.17  1568380368
# 1             81           0        4.10  1568380158
# 2             59           0        1.63  1568380368
# 3             75          75        7.24  1568380369
# 4             73          78        0.92  1568380369

# %%
weather_df = weather_df.append(weather400_df, ignore_index = True) 
weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-f4a955f2eb2f> in <module>
# ----> 1 weather_df = weather_df.append(weather400_df,ignore_index = True)
#       2 weather_df.head()
#
# TypeError: append() takes no keyword arguments

# %%
weather_df = weather_df.append(weather500_df, ignore_index = True) 
weather_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-4020d9ca696f> in <module>
# ----> 1 weather_df = weather_df.append(weather500_df, ignore_index = True)
#       2 weather_df.head()
#
# TypeError: append() takes no keyword arguments

# %%
weather_df = weather_df.append(weather600_df,ignore_index = True) 
weather_df.head()

# %%
weather_df = weather_df.to_csv('weather.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-fb3538e649ce> in <module>
# ----> 1 weather_df = weather_df.to_csv('weather.csv', index=False)
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
AllCity_load = "AllCity.csv" 
AllCity_df = pd.read_csv(AllCity_load) 
AllCity_df = pd.DataFrame(AllCity_df)

# %%
citySample_df = cityGrab_df[['NAME']].merge(AllCity_df[['NAME', 'UWM_ID']], on='NAME', how='left') 
citySample_df = citySample_df.dropna(how="any")
cityCodes_df = citySample_df['UWM_ID'].astype(np.int64)
cityCodes_df = pd.DataFrame(cityCodes_df)
